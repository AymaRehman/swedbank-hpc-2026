# %%
import sys
sys.path.append('../src')

import matplotlib.patches as mpatches
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import re
from wordcloud import STOPWORDS, WordCloud
from config import DATA_PROCESSED_PATH, DATA_RAW_PATH

# %%
BG_COLOR = '#F7FAFC'
HAM_COLOR = '#ADCBD7'
SPAM_COLOR = '#7FA1C3'

# %%
df = pd.read_csv(DATA_PROCESSED_PATH)
df = df.rename(columns={'message': 'text'})
df['message_length'] = df['text'].fillna('').apply(len)

label_count = df['label'].value_counts()

plt.figure(figsize=(10,4))
plt.pie(label_count, labels=['Ham', 'Spam'], autopct='%1.2f%%',colors = [HAM_COLOR, SPAM_COLOR])
plt.title('Distribution of Ham versus Spam messages')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 4))  
fig.patch.set_facecolor(BG_COLOR)
ax.set_facecolor(BG_COLOR)
ax.set_xlim(-0.5, 1.5)

bars = ax.bar(['Ham', 'Spam'], label_count.values, color=['#ADCBD7', '#7FA1C3'],
              edgecolor='white', width=0.4)

for bar, val in zip(bars, label_count.values):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 20,
            str(val), ha='center', fontsize=11, fontweight='bold', color='#333')

ax.set_title('Class distribution', fontsize=14, fontweight='bold', pad=12)
ax.set_ylabel('Number of messages', fontsize=11, labelpad=8)
ax.set_ylim(0, label_count.max() * 1.12)

for spine in ax.spines.values():
    spine.set_visible(False)
ax.yaxis.grid(True, color='white', linewidth=1.5)
ax.set_axisbelow(True)
ax.tick_params(left=False, labelsize=11)

plt.tight_layout()
plt.show()

# %%
def style_table(data_style):
    return( data_style.style
        .hide(axis='index')
        .set_table_styles([ #properties of column headers
            {'selector': 'th',
            'props':
                [('background-color', '#002D4C'),
                ('color','white'),
                ('border','1px solid #3b3b3b'),]}
    ])
        .set_properties(**{  #properties of each cell
            'background-color': '#ADC9E4',
            'color': 'black',
            'text-align': 'center',
            'border':'1px solid #3b3b3b'})

        .set_properties(subset=['Message length'],**{
            'background-color': '#E1EBEE'})

        .highlight_max(
            subset=['Ham messages','Spam messages'],
            axis = 0,
            props = 'background-color: #7FA1C3;')
)

bins = [0, 50, 100, 200, 300, 400, 500, 1000]
range_labels = ['1-50','51- 100','101-200','201-300','301-400','401-500','500+']

data = (df.groupby([pd.cut(df['message_length'],bins = bins, labels=range_labels),'label'])
        .size()
        .unstack(fill_value=0)
        .rename(columns={0: 'Ham messages', 1: 'Spam messages'}) 
        .reset_index()
        .rename(columns={'message_length': 'Message length'}))

style_table(data)
# Out:
# <style type="text/css">
# #T_f965a th {
#   background-color: #002D4C;
#   color: white;
#   border: 1px solid #3b3b3b;
# }
# #T_f965a_row0_col0, #T_f965a_row1_col0, #T_f965a_row2_col0, #T_f965a_row3_col0, #T_f965a_row4_col0, #T_f965a_row5_col0, #T_f965a_row6_col0 {
#   background-color: #ADC9E4;
#   color: black;
#   text-align: center;
#   border: 1px solid #3b3b3b;
#   background-color: #E1EBEE;
# }
# #T_f965a_row0_col1, #T_f965a_row2_col2 {
#   background-color: #ADC9E4;
#   color: black;
#   text-align: center;
#   border: 1px solid #3b3b3b;
#   background-color: #7FA1C3;
# }
# #T_f965a_row0_col2, #T_f965a_row1_col1, #T_f965a_row1_col2, #T_f965a_row2_col1, #T_f965a_row3_col1, #T_f965a_row3_col2, #T_f965a_row4_col1, #T_f965a_row4_col2, #T_f965a_row5_col1, #T_f965a_row5_col2, #T_f965a_row6_col1, #T_f965a_row6_col2 {
#   background-color: #ADC9E4;
#   color: black;
#   text-align: center;
#   border: 1px solid #3b3b3b;
# }
# </style>
# <table id="T_f965a">
#   <thead>
#     <tr>
#       <th id="T_f965a_level0_col0" class="col_heading level0 col0" >Message length</th>
#       <th id="T_f965a_level0_col1" class="col_heading level0 col1" >Ham messages</th>
#       <th id="T_f965a_level0_col2" class="col_heading level0 col2" >Spam messages</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f965a_row0_col0" class="data row0 col0" >1-50</td>
#       <td id="T_f965a_row0_col1" class="data row0 col1" >2313</td>
#       <td id="T_f965a_row0_col2" class="data row0 col2" >20</td>
#     </tr>
#     <tr>
#       <td id="T_f965a_row1_col0" class="data row1 col0" >51- 100</td>
#       <td id="T_f965a_row1_col1" class="data row1 col1" >1298</td>
#       <td id="T_f965a_row1_col2" class="data row1 col2" >63</td>
#     </tr>
#     <tr>
#       <td id="T_f965a_row2_col0" class="data row2 col0" >101-200</td>
#       <td id="T_f965a_row2_col1" class="data row2 col1" >799</td>
#       <td id="T_f965a_row2_col2" class="data row2 col2" >547</td>
#     </tr>
#     <tr>
#       <td id="T_f965a_row3_col0" class="data row3 col0" >201-300</td>
#       <td id="T_f965a_row3_col1" class="data row3 col1" >62</td>
#       <td id="T_f965a_row3_col2" class="data row3 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_f965a_row4_col0" class="data row4 col0" >301-400</td>
#       <td id="T_f965a_row4_col1" class="data row4 col1" >14</td>
#       <td id="T_f965a_row4_col2" class="data row4 col2" >0</td>
#     </tr>
#     <tr>
#       <td id="T_f965a_row5_col0" class="data row5 col0" >401-500</td>
#       <td id="T_f965a_row5_col1" class="data row5 col1" >7</td>
#       <td id="T_f965a_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#     <tr>
#       <td id="T_f965a_row6_col0" class="data row6 col0" >500+</td>
#       <td id="T_f965a_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_f965a_row6_col2" class="data row6 col2" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
def style_words(data_style):
    return(data_style.style
           .hide(axis='index')
           .set_properties(**{ #properties of each cell
                'font-size': '14px',
                'color': 'black',
                'text-align': 'center',
                'border':'1px solid #3b3b3b'})
           .set_properties(**{ #properties of the first two columns
                'background-color': '#ADC9E4'},subset=data_style.columns[0:2])
           .set_properties(**{ #properties of the last two columns
                'background-color': '#7FA1C3'},subset=data_style.columns[2:4])
           .set_table_styles([ #properties of column headers
                {'selector': 'th','props': [
                    ('background-color', '#002D4C'),
                    ('color','white'),
                    ('text-align','center'),
                    ('font-size','16px'),
                    ('border','1px solid #3b3b3b')]}
        ]))


def get_top_words(group, n = 10):
    clean_group = group.dropna().astype(str)
    full_text = " ".join(clean_group).lower()
    words = re.findall(r'\b\w{3,}\b', full_text) #Words that are less than 3 letters are ignored in the table

    filtered = [w for w in words if w not in stop_words]
    return pd.DataFrame(Counter(filtered).most_common(n), columns = ['word','count'])


stop_words = set(STOPWORDS)


spam_data = get_top_words(df[df['label'] == 1]['text']) 
ham_data = get_top_words(df[df['label'] == 0]['text']) 
top_words_df = pd.concat([spam_data,ham_data],axis=1)

top_words_df.columns = pd.MultiIndex.from_tuples([('SPAM','Word'),('SPAM','Frequency'),('HAM','Word'),('HAM','Frequency')])

style_words(top_words_df)
# Out:
# <style type="text/css">
# #T_a4085 th {
#   background-color: #002D4C;
#   color: white;
#   text-align: center;
#   font-size: 16px;
#   border: 1px solid #3b3b3b;
# }
# #T_a4085_row0_col0, #T_a4085_row0_col1, #T_a4085_row1_col0, #T_a4085_row1_col1, #T_a4085_row2_col0, #T_a4085_row2_col1, #T_a4085_row3_col0, #T_a4085_row3_col1, #T_a4085_row4_col0, #T_a4085_row4_col1, #T_a4085_row5_col0, #T_a4085_row5_col1, #T_a4085_row6_col0, #T_a4085_row6_col1, #T_a4085_row7_col0, #T_a4085_row7_col1, #T_a4085_row8_col0, #T_a4085_row8_col1, #T_a4085_row9_col0, #T_a4085_row9_col1 {
#   font-size: 14px;
#   color: black;
#   text-align: center;
#   border: 1px solid #3b3b3b;
#   background-color: #ADC9E4;
# }
# #T_a4085_row0_col2, #T_a4085_row0_col3, #T_a4085_row1_col2, #T_a4085_row1_col3, #T_a4085_row2_col2, #T_a4085_row2_col3, #T_a4085_row3_col2, #T_a4085_row3_col3, #T_a4085_row4_col2, #T_a4085_row4_col3, #T_a4085_row5_col2, #T_a4085_row5_col3, #T_a4085_row6_col2, #T_a4085_row6_col3, #T_a4085_row7_col2, #T_a4085_row7_col3, #T_a4085_row8_col2, #T_a4085_row8_col3, #T_a4085_row9_col2, #T_a4085_row9_col3 {
#   font-size: 14px;
#   color: black;
#   text-align: center;
#   border: 1px solid #3b3b3b;
#   background-color: #7FA1C3;
# }
# </style>
# <table id="T_a4085">
#   <thead>
#     <tr>
#       <th id="T_a4085_level0_col0" class="col_heading level0 col0" colspan="2">SPAM</th>
#       <th id="T_a4085_level0_col2" class="col_heading level0 col2" colspan="2">HAM</th>
#     </tr>
#     <tr>
#       <th id="T_a4085_level1_col0" class="col_heading level1 col0" >Word</th>
#       <th id="T_a4085_level1_col1" class="col_heading level1 col1" >Frequency</th>
#       <th id="T_a4085_level1_col2" class="col_heading level1 col2" >Word</th>
#       <th id="T_a4085_level1_col3" class="col_heading level1 col3" >Frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a4085_row0_col0" class="data row0 col0" >call</td>
#       <td id="T_a4085_row0_col1" class="data row0 col1" >291</td>
#       <td id="T_a4085_row0_col2" class="data row0 col2" >will</td>
#       <td id="T_a4085_row0_col3" class="data row0 col3" >306</td>
#     </tr>
#     <tr>
#       <td id="T_a4085_row1_col0" class="data row1 col0" >gbp</td>
#       <td id="T_a4085_row1_col1" class="data row1 col1" >261</td>
#       <td id="T_a4085_row1_col2" class="data row1 col2" >now</td>
#       <td id="T_a4085_row1_col3" class="data row1 col3" >270</td>
#     </tr>
#     <tr>
#       <td id="T_a4085_row2_col0" class="data row2 col0" >free</td>
#       <td id="T_a4085_row2_col1" class="data row2 col1" >178</td>
#       <td id="T_a4085_row2_col2" class="data row2 col2" >ltgt</td>
#       <td id="T_a4085_row2_col3" class="data row2 col3" >254</td>
#     </tr>
#     <tr>
#       <td id="T_a4085_row3_col0" class="data row3 col0" >now</td>
#       <td id="T_a4085_row3_col1" class="data row3 col1" >152</td>
#       <td id="T_a4085_row3_col2" class="data row3 col2" >dont</td>
#       <td id="T_a4085_row3_col3" class="data row3 col3" >253</td>
#     </tr>
#     <tr>
#       <td id="T_a4085_row4_col0" class="data row4 col0" >txt</td>
#       <td id="T_a4085_row4_col1" class="data row4 col1" >121</td>
#       <td id="T_a4085_row4_col2" class="data row4 col2" >got</td>
#       <td id="T_a4085_row4_col3" class="data row4 col3" >225</td>
#     </tr>
#     <tr>
#       <td id="T_a4085_row5_col0" class="data row5 col0" >stop</td>
#       <td id="T_a4085_row5_col1" class="data row5 col1" >103</td>
#       <td id="T_a4085_row5_col2" class="data row5 col2" >know</td>
#       <td id="T_a4085_row5_col3" class="data row5 col3" >221</td>
#     </tr>
#     <tr>
#       <td id="T_a4085_row6_col0" class="data row6 col0" >text</td>
#       <td id="T_a4085_row6_col1" class="data row6 col1" >101</td>
#       <td id="T_a4085_row6_col2" class="data row6 col2" >come</td>
#       <td id="T_a4085_row6_col3" class="data row6 col3" >208</td>
#     </tr>
#     <tr>
#       <td id="T_a4085_row7_col0" class="data row7 col0" >mobile</td>
#       <td id="T_a4085_row7_col1" class="data row7 col1" >99</td>
#       <td id="T_a4085_row7_col2" class="data row7 col2" >ill</td>
#       <td id="T_a4085_row7_col3" class="data row7 col3" >207</td>
#     </tr>
#     <tr>
#       <td id="T_a4085_row8_col0" class="data row8 col0" >claim</td>
#       <td id="T_a4085_row8_col1" class="data row8 col1" >95</td>
#       <td id="T_a4085_row8_col2" class="data row8 col2" >good</td>
#       <td id="T_a4085_row8_col3" class="data row8 col3" >204</td>
#     </tr>
#     <tr>
#       <td id="T_a4085_row9_col0" class="data row9 col0" >reply</td>
#       <td id="T_a4085_row9_col1" class="data row9 col1" >90</td>
#       <td id="T_a4085_row9_col2" class="data row9 col2" >time</td>
#       <td id="T_a4085_row9_col3" class="data row9 col3" >181</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
fig.subplots_adjust(wspace=0.1)

for ax, label, title in zip(axes, [1, 0], ['Spam', 'Ham']):
    words = get_top_words(df[df['label'] == label]['text'], n=150)
    wc = WordCloud(
        background_color='white',
        width=800,
        height=400,
        colormap='YlGnBu',
        max_words=150,
        contour_width=1,
    ).generate_from_frequencies(dict(words.values))
    ax.imshow(wc, interpolation='bilinear')
    ax.axis('off')
    ax.set_title(f'{title} Word Cloud', fontsize=14, fontweight='bold', pad = 10)

plt.tight_layout()
plt.show()

# %%
spam_large = get_top_words(df[df['label'] == 1]['text'], n=150)
ham_large = get_top_words(df[df['label'] == 0]['text'], n=150)

common_words ={**dict(spam_large.values), **dict(ham_large.values)}

wc = WordCloud(
    background_color = 'white',
    width = 800,
    height = 400,
    colormap = 'YlGnBu',
    max_words = 150, #To display less words, change max_words parameter
    contour_width= 1,

).generate_from_frequencies(common_words)

plt.figure(figsize=(10,6))
plt.imshow(wc, interpolation='bilinear')
plt.title("Combined Word Cloud",fontsize=14, fontweight='bold', pad = 10)
plt.axis("off")
plt.show()
